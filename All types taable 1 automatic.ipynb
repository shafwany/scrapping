# %%
import pandas as pd
import json
import requests

# %%
custtyped ={
    'Customer Type':['atm','bank','mosque','department_store','bakery','accounting',
                    'airport','amusement_park','aquarium','art_gallery','bar','beauty_salon','bicycle_store',
                     'book_store','bowling_alley','bus_station','cafe','campground','car_dealer','car_rental'
                     'car_repair','car_wash','casino','cemetery','church','city_hall','clothing_store','convenience_store',
                     'courthouse','dentist','doctor','drugstore','electrician',
                     'electronics_store','embassy','fire_station','florist','funeral_home','furniture_store',
                     'gas_station','gym','hair_care','hardware_store','hindu_temple','home_goods_store',
                     'hospital','insurance_agency','jewelry_store','laundry','lawyer','library','light_rail_station',
                     'liquor_store','local_government_office','locksmith','lodging','meal_delivery',
                     'meal_takeaway','movie_rental','movie_theater','moving_company','museum','night_club',
                     'painter','park','parking','pet_store','pharmacy','physiotherapist','plumber','police',
                     'post_office','primary_school','real_estate_agency','restaurant','roofing_contractor',
                      'rv_park','school','secondary_school','shoe_store','shopping_mall','spa','stadium',
                      'storage','store','subway_station','supermarket','synagogue','taxi_stand',
                      'tourist_attraction','train_station','transit_station','travel_agency','university',
                      'veterinary_care','zoo']
    #'Keyword':['Mandiri','BCA','istiqlal','matahari','breadtalk']
}

# %%
custtype=pd.DataFrame(custtyped)
custtype
# Out:
#        Customer Type
# 0                atm
# 1               bank
# 2             mosque
# 3   department_store
# 4             bakery
# ..               ...
# 90   transit_station
# 91     travel_agency
# 92        university
# 93   veterinary_care
# 94               zoo
#
# [95 rows x 1 columns]

# %%
custtype['Customer Type'].values
# Out:
# array(['atm', 'bank', 'mosque', 'department_store', 'bakery',
#        'accounting', 'airport', 'amusement_park', 'aquarium',
#        'art_gallery', 'bar', 'beauty_salon', 'bicycle_store',
#        'book_store', 'bowling_alley', 'bus_station', 'cafe', 'campground',
#        'car_dealer', 'car_rentalcar_repair', 'car_wash', 'casino',
#        'cemetery', 'church', 'city_hall', 'clothing_store',
#        'convenience_store', 'courthouse', 'dentist', 'doctor',
#        'drugstore', 'electrician', 'electronics_store', 'embassy',
#        'fire_station', 'florist', 'funeral_home', 'furniture_store',
#        'gas_station', 'gym', 'hair_care', 'hardware_store',
#        'hindu_temple', 'home_goods_store', 'hospital', 'insurance_agency',
#        'jewelry_store', 'laundry', 'lawyer', 'library',
#        'light_rail_station', 'liquor_store', 'local_government_office',
#        'locksmith', 'lodging', 'meal_delivery', 'meal_takeaway',
#        'movie_rental', 'movie_theater', 'moving_company', 'museum',
#        'night_club', 'painter', 'park', 'parking', 'pet_store',
#        'pharmacy', 'physiotherapist', 'plumber', 'police', 'post_office',
#        'primary_school', 'real_estate_agency', 'restaurant',
#        'roofing_contractor', 'rv_park', 'school', 'secondary_school',
#        'shoe_store', 'shopping_mall', 'spa', 'stadium', 'storage',
#        'store', 'subway_station', 'supermarket', 'synagogue',
#        'taxi_stand', 'tourist_attraction', 'train_station',
#        'transit_station', 'travel_agency', 'university',
#        'veterinary_care', 'zoo'], dtype=object)

# %%
data_cust={}
latitude, longitude, name, place_id, types_places, vicinity = [],[],[],[],[],[]

for types in custtype['Customer Type'].values:
    apik = 'AIzaSyCi3bprtv8GbZUNpU4rE2eQ8oguxfDkRjg'
    urls = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-6.1798024,106.8220712&radius=1000&key={}&type={}'.format(apik,types)
    r = requests.get(urls)
    data_cust[types] = r.json()
    for number in range(len(data_cust[types]['results'])):
        latitude.append(data_cust[types]['results'][number]['geometry']['location']['lat'])
        longitude.append(data_cust[types]['results'][number]['geometry']['location']['lng'])
        name.append(data_cust[types]['results'][number]['name'])
        place_id.append(data_cust[types]['results'][number]['place_id'])
        types_places.append(data_cust[types]['results'][number]['types'][0])
        vicinity.append(data_cust[types]['results'][number]['vicinity'])

# %%
datacustype = pd.DataFrame({'name':name,'place_id':place_id,'types':types_places,'latitude':latitude,
                     'longitude':longitude,'address':vicinity})
datacustype
# Out:
#                                     name                     place_id  \
# 0                                ATM BCA  ChIJkVl3Cyb0aS4RreuLHC1jVVs
# 1                           Bank Mandiri  ChIJ4aK0ASb0aS4RtBpG6E47-KU
# 2           ATM Muamalat SPBU Abdul Muis  ChIJ57QLxyr0aS4RT1xV2ruHnWQ
# 3         ATM Bank Mandiri Setoran Tunai  ChIJ94bINy70aS4RbUmWL0D6UrQ
# 4                        Wisma Mandiri 2  ChIJ_yLtR4L2aS4RQajwWGcodnc
# ..                                   ...                          ...
# 220                Rental ELF 15-19 Seat  ChIJ29-JYX_2aS4RNbxVsUJVYJk
# 221             Sewa Mobil Murah HD Rent  ChIJhUA-nHX1aS4R3C8zccbW9aw
# 222  Rental mobil Gambir | Elsa rent car  ChIJRy1_hET3aS4RtSxpFi8yLmQ
# 223                Rental Putra Dewa Cbk  ChIJwcb0pYv1aS4RwMPMeW4ZYy4
# 224                Sewa mobil innova HDR  ChIJMXN112v1aS4RSPuedCNLwT0
#
#           types  latitude   longitude  \
# 0           atm -6.187770  106.823922
# 1          bank -6.187334  106.823601
# 2           atm -6.178355  106.818414
# 3           atm -6.183710  106.823645
# 4          bank -6.184070  106.823523
# ..          ...       ...         ...
# 220  car_rental -6.173132  106.817717
# 221  car_rental -6.185073  106.828367
# 222  car_rental -6.180555  106.813822
# 223  car_rental -6.187180  106.818271
# 224  car_rental -6.185634  106.828251
#
#                                                address
# 0      Jalan M.H. Thamrin No.11, RT.8/RW.4, Gondangdia
# 1      Jalan M.H. Thamrin No.11, RT.8/RW.4, Gondangdia
# 2    Jalan Abdul Muis No. 59, RT.4/RW.3, Petojo Sel...
# 3    Wisma Mandiri, Jalan Kebon Sirih No.83, RT.2/R...
# 4      Jalan Kebon Sirih No.83, RT.2/RW.1, Kebon Sirih
# ..                                                 ...
# 220  Jalan Petojo Enclek XIII No.22, RT.16/RW.7, Pe...
# 221  Jalan Kebon Sirih Barat I No.33-35, RT.13/RW.2...
# 222   13, Jalan Kebon Jahe No.54, RW.2, Petojo Selatan
# 223                         2, RT.5/RW.5, Kebon Kacang
# 224                             RT.8/RW.4, Kebon Sirih
#
# [225 rows x 6 columns]

# %% [markdown]
# # cleaning

# %%
pd.isnull(datacustype).sum()
# Out:
# name         0
# place_id     0
# types        0
# latitude     0
# longitude    0
# address      0
# dtype: int64

# %%
len(datacustype['place_id'].unique())
# Out:
# 212

# %% [markdown]
# # phone numb

# %%
data_number = {}
for number in datacustype['place_id'].values:
    apik = 'AIzaSyCi3bprtv8GbZUNpU4rE2eQ8oguxfDkRjg'
    urls = 'https://maps.googleapis.com/maps/api/place/details/json?place_id={}&fields=name,rating,formatted_phone_number&key={}'.format(number,apik)
    r = requests.get(urls)
    data_number[number] = r.json()

# %%
data_number
# Out:
# {'ChIJkVl3Cyb0aS4RreuLHC1jVVs': {'html_attributions': [],
#   'result': {'name': 'ATM BCA', 'rating': 4.5},
#   'status': 'OK'},
#  'ChIJ4aK0ASb0aS4RtBpG6E47-KU': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 2300644',
#    'name': 'Bank Mandiri',
#    'rating': 3.7},
#   'status': 'OK'},
#  'ChIJ57QLxyr0aS4RT1xV2ruHnWQ': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 1500016',
#    'name': 'ATM Muamalat SPBU Abdul Muis',
#    'rating': 4},
#   'status': 'OK'},
#  'ChIJ94bINy70aS4RbUmWL0D6UrQ': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 2302411',
#    'name': 'ATM Bank Mandiri Setoran Tunai',
#    'rating': 4.4},
#   'status': 'OK'},
#  'ChIJ_yLtR4L2aS4RQajwWGcodnc': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 2302411',
#    'name': 'Wisma Mandiri 2',
#    'rating': 4.2},
#   'status': 'OK'},
#  'ChIJN84MlNT1aS4R9RzBpYTEojk': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 52997777',
#    'name': 'Mandiri ATM KCP Jakarta Gedung Depparpostel',
#    'rating': 4.7},
#   'status': 'OK'},
#  'ChIJVcmszNT1aS4RwbX0jl6Zfao': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3149039',
#    'name': 'PT. Bank Negara Indonesia Persero Tbk',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJQdHVYS70aS4Rxvwlm6N_58o': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3500437',
#    'name': 'PT. Bank Rakyat Indonesia Persero Tbk',
#    'rating': 3.3},
#   'status': 'OK'},
#  'ChIJAZs2lCv0aS4RmiTJpV4nxr8': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 57899999',
#    'name': 'ATM BNI INDOSAT PUSAT',
#    'rating': 4.8},
#   'status': 'OK'},
#  'ChIJb1gXjSv0aS4RmbIRpsNYF9E': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 500888',
#    'name': 'ATM Bank BCA 4351-Gedung Indosat',
#    'rating': 3.8},
#   'status': 'OK'},
#  'ChIJxY-DASz0aS4RAwxau8n6IIw': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3867496',
#    'name': 'Bank Mandiri Jakarta Gedung Depparpostel',
#    'rating': 2.5},
#   'status': 'OK'},
#  'ChIJa0gFCSv0aS4R5UrOuZ7UqrA': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 52997777',
#    'name': 'ATM Mandiri',
#    'rating': 4.3},
#   'status': 'OK'},
#  'ChIJR4e0yCv0aS4R33Mk1hwMieA': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 29573891',
#    'name': 'ATM PT. Bank Negara Indonesia (Persero) Tbk',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJS8Z1TCr0aS4RZ9Xwvmbsj28': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 57899999',
#    'name': 'BNI',
#    'rating': 4.5},
#   'status': 'OK'},
#  'ChIJnb9o2Sv0aS4Rhv7bqHKNoVg': {'html_attributions': [],
#   'result': {'name': 'Atm Bank Mandiri'},
#   'status': 'OK'},
#  'ChIJmVEx1yv0aS4RvWSbD7FmSdo': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 57899999',
#    'name': 'ATM LINK (BNI) BI GEDUNG B',
#    'rating': 4},
#   'status': 'OK'},
#  'ChIJz8X1FSv0aS4RnlGa484ZwfY': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 57899999',
#    'name': 'ATM BNI MENKO POLKAM'},
#   'status': 'OK'},
#  'ChIJo-Uxmyn0aS4RzA_4qTPht00': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 52997777',
#    'name': 'ATM Mandiri'},
#   'status': 'OK'},
#  'ChIJv_nANyr0aS4RmWjccz_eiYI': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 52997777',
#    'name': 'Mandiri ATM KCP Jakarta Caltex Pacific Indonesia'},
#   'status': 'OK'},
#  'ChIJz4-DASz0aS4RHq5eQAANybw': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 57899999',
#    'name': 'ATM BNI WISMA ANTARA'},
#   'status': 'OK'},
#  'ChIJN47oviv0aS4RV9VUw3DujB4': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3828403', 'name': 'Mandiri'},
#   'status': 'OK'},
#  'ChIJZd_7Lyz0aS4R1Tpt2YnzwQs': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 2313306',
#    'name': 'Bank DKI KCU Balaikota',
#    'rating': 4.1},
#   'status': 'OK'},
#  'ChIJd7CgldT1aS4RrtJxWnsOu8s': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3828152',
#    'name': 'BNI DEPARTEMEN PERTAHANAN',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJl6wN6y70aS4RVN3Z1qOLLQM': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3927467',
#    'name': 'Bank Negara Indonesia - KLN Bimantara',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJX8PRLtT1aS4RFsARwtmhebo': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3500870',
#    'name': 'Bank Negara Indonesia - KLN Departemen Perhubungan',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJA-6-USn0aS4RBwhMlG44Bs0': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 31990101',
#    'name': 'Bank Shinta Indonesia. PT',
#    'rating': 4.5},
#   'status': 'OK'},
#  'ChIJjYUSlSv0aS4RgGhvrnXEOAU': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3518075',
#    'name': "PT. Cont'd Bank DKI"},
#   'status': 'OK'},
#  'ChIJIYcuXCn0aS4RW1T3hhEKD4c': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 31996944',
#    'name': 'Bank Mandiri - Branch Jakarta Kebun Melati',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJR0acfyn0aS4RJpC4p-F9k14': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 57899999',
#    'name': 'ATM BNI BI GEDUNG "TYPIKAL"',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJ1a2qhSn0aS4RHS7walswctE': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 57899999',
#    'name': 'ATM BNI BI GEDUNG D'},
#   'status': 'OK'},
#  'ChIJDz3T9ir0aS4RE4YIisiMwIg': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 29818457',
#    'name': 'Baitul Ihsan',
#    'rating': 4.8},
#   'status': 'OK'},
#  'ChIJI2Mi6dT1aS4R_9QvMw2LbMA': {'html_attributions': [],
#   'result': {'name': 'Masjid At-Taqwa', 'rating': 4.6},
#   'status': 'OK'},
#  'ChIJzRh38tT1aS4RKCRxTOnaJGw': {'html_attributions': [],
#   'result': {'formatted_phone_number': '21123',
#    'name': 'Masjid Al-Hidayah Kementerian Perhubungan Republik Indonesia',
#    'rating': 4.3},
#   'status': 'OK'},
#  'ChIJY4JB7dX1aS4RTixX44Ml7WA': {'html_attributions': [],
#   'result': {'name': 'MASJID WALIKOTA JAKARTA PUSAT', 'rating': 4.8},
#   'status': 'OK'},
#  'ChIJtcGPOCb0aS4RqkaNusHU0kA': {'html_attributions': [],
#   'result': {'name': 'Masjid Alfurqon', 'rating': 4.5},
#   'status': 'OK'},
#  'ChIJo4GjwCv0aS4RR07fUNdQEew': {'html_attributions': [],
#   'result': {'name': 'Masjid Nurul Taqwa Indosat Ooredoo', 'rating': 4.9},
#   'status': 'OK'},
#  'ChIJG9ZBECv0aS4RPjJKLHGzZU0': {'html_attributions': [],
#   'result': {'name': 'MASJID DAARUSSALAAM', 'rating': 5},
#   'status': 'OK'},
#  'ChIJCVaPQCv0aS4R0LQf87JD3Fs': {'html_attributions': [],
#   'result': {'name': 'Masjid Nurul Aman'},
#   'status': 'OK'},
#  'ChIJ1ScSBiz0aS4RlFXNe3a4KCs': {'html_attributions': [],
#   'result': {'name': 'Mesjid Daaruttaqwa', 'rating': 4.7},
#   'status': 'OK'},
#  'ChIJtxr7bSz0aS4RtkpbepsFN40': {'html_attributions': [],
#   'result': {'name': 'Masjid An Nur', 'rating': 4.5},
#   'status': 'OK'},
#  'ChIJ__8_Aiz0aS4RMq84IqUZJ6I': {'html_attributions': [],
#   'result': {'name': 'Masjid Darrut Taqwa', 'rating': 4.8},
#   'status': 'OK'},
#  'ChIJYb59ASz0aS4RtBEpd2MX3VE': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3511191',
#    'name': 'Musholla Addarut Taqwa',
#    'rating': 4},
#   'status': 'OK'},
#  'ChIJM_wW3Cr0aS4Rt_o4d4Rc588': {'html_attributions': [],
#   'result': {'name': 'Masjid At Taqwa - Kementrian Pertahanan RI',
#    'rating': 4.7},
#   'status': 'OK'},
#  'ChIJYT4Xnyr0aS4Rs5eubrMOoik': {'html_attributions': [],
#   'result': {'name': 'Masjid Al Badr', 'rating': 4.8},
#   'status': 'OK'},
#  'ChIJM1KCnCr0aS4RGAe0nZPwbX8': {'html_attributions': [],
#   'result': {'name': 'Musholla SPBU 31.102.02', 'rating': 4.3},
#   'status': 'OK'},
#  'ChIJDdCDMdX1aS4R8-fORPjzk94': {'html_attributions': [],
#   'result': {'name': 'Masjid Ar-Rahmah', 'rating': 5},
#   'status': 'OK'},
#  'ChIJ4cwg6y70aS4Rmi60ABjBgEk': {'html_attributions': [],
#   'result': {'name': 'Masjid Ar-Rayyan', 'rating': 4.7},
#   'status': 'OK'},
#  'ChIJSZYq_RT1aS4RIMGdBH6f9Rk': {'html_attributions': [],
#   'result': {'name': 'Masjid Al Ihsan BSM', 'rating': 4.9},
#   'status': 'OK'},
#  'ChIJ4YvOJdX1aS4Rces7LnYfgBU': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3442506',
#    'name': 'Masjid Arrohah',
#    'rating': 4.7},
#   'status': 'OK'},
#  'ChIJ7fo4qyn0aS4RGUugb5dupaQ': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3909497',
#    'name': 'Masjid Al Ihsan',
#    'rating': 4.8},
#   'status': 'OK'},
#  'ChIJ4aK0ASb0aS4RJvFYZjAod84': {'html_attributions': [],
#   'result': {'name': 'Java', 'rating': 5},
#   'status': 'OK'},
#  'ChIJuf0yYmP1aS4RABndlp8cHog': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0857-8295-0646',
#    'name': 'Handphone Accesoris Hp dan Service Hp'},
#   'status': 'OK'},
#  'ChIJY8xXuSr0aS4RlYxoGKKIaBU': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3854755',
#    'name': 'PT. Barataguna Indoganesha',
#    'rating': 3.8},
#   'status': 'OK'},
#  'ChIJvZJYPS_0aS4R1PXqoP5lKIM': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3904650',
#    'name': 'Cardo Lestari Indonesia. PT',
#    'rating': 3.8},
#   'status': 'OK'},
#  'ChIJpeBz1Cf0aS4RBstiaiOFX3k': {'html_attributions': [],
#   'result': {'name': 'Ramayana Dept. Store', 'rating': 1},
#   'status': 'OK'},
#  'ChIJu_xCVIL2aS4RdsznZ_xx2Uk': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3159065',
#    'name': 'Brahmana Dept Store'},
#   'status': 'OK'},
#  'ChIJ7VieKi_0aS4RT3StCIsUhUQ': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 29932755',
#    'name': 'Sari Delicatessen',
#    'rating': 4.3},
#   'status': 'OK'},
#  'ChIJMxQfF4L2aS4RMZdVI3d5ra8': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 2303636',
#    'name': 'Art and Bakery Corner',
#    'rating': 2.5},
#   'status': 'OK'},
#  'ChIJ_UFU6yj0aS4RWLItwmL4SIo': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 26780003',
#    'name': 'Double Dipps',
#    'rating': 2},
#   'status': 'OK'},
#  'ChIJX7jblSj0aS4RJMGwEhjv5p8': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 31908236',
#    'name': 'Home Made Bakery - Menara Thamrin',
#    'rating': 4.7},
#   'status': 'OK'},
#  'ChIJuYos6yj0aS4RImWrQ1Yn0FQ': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3147022',
#    'name': 'Daily Bread',
#    'rating': 4},
#   'status': 'OK'},
#  'ChIJV3JslCj0aS4RLAqixbMRsaU': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3158877',
#    'name': 'Kinokawa',
#    'rating': 4.5},
#   'status': 'OK'},
#  'ChIJdYBPPC_0aS4R0P7ZCeeC7b4': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 22346350',
#    'name': "Dunkin' Donuts Sabang",
#    'rating': 4.3},
#   'status': 'OK'},
#  'ChIJ1wmkVS_0aS4R60bJyQQ3dk0': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3152627',
#    'name': 'Daily Bread',
#    'rating': 3},
#   'status': 'OK'},
#  'ChIJE6XGJSb0aS4RM7LGV2VP5uE': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 1500581',
#    'name': 'The Harvest Cakes - Thamrin',
#    'rating': 4.3},
#   'status': 'OK'},
#  'ChIJO04zPZ32aS4R0KITGrWF12I': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0857-7354-3121',
#    'name': 'Rica Rico Bika Ambon',
#    'rating': 4.6},
#   'status': 'OK'},
#  'ChIJSaJzPiH0aS4RHT4fHt69ceQ': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 29924358',
#    'name': 'DORÉ by LeTAO Plaza Indonesia',
#    'rating': 4.4},
#   'status': 'OK'},
#  'ChIJ7UrAsTL0aS4R3-wUx1oKuco': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3517147',
#    'name': 'Krispy Kreme',
#    'rating': 4.3},
#   'status': 'OK'},
#  'ChIJrfbkzvL1aS4Rj-9ra4yRWj0': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0816-1161-092',
#    'name': 'Roti Bang Eja'},
#   'status': 'OK'},
#  'ChIJe53G7Cr0aS4RVt3CU9vx09w': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 6128811', 'name': 'Patisserie'},
#   'status': 'OK'},
#  'ChIJg4qiuiH0aS4RDB3DtatwXvY': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0811-9876-668',
#    'name': 'LA MAISON Grand Indonesia',
#    'rating': 4.3},
#   'status': 'OK'},
#  'ChIJGfY6lAD1aS4RD0xb1eSgHrA': {'html_attributions': [],
#   'result': {'name': 'Holland Bakery SPBU', 'rating': 4.4},
#   'status': 'OK'},
#  'ChIJo7LhuSn0aS4RAdzTdKk7f1A': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 31933212',
#    'name': 'Milano Bakery & Cake',
#    'rating': 4.8},
#   'status': 'OK'},
#  'ChIJ15SGwCn0aS4RgBfKPYZAgAk': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 31906864',
#    'name': 'Vilano Bakery',
#    'rating': 3.5},
#   'status': 'OK'},
#  'ChIJK-MqtoD1aS4R0qKEI_ggtRM': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 31905390',
#    'name': 'Monami Sabang',
#    'rating': 4.6},
#   'status': 'OK'},
#  'ChIJlRR73y70aS4RKM9L3hFvqRE': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3144253',
#    'name': 'Sakura anpan Cake Shop',
#    'rating': 4.4},
#   'status': 'OK'},
#  'ChIJ62U3CFfxaS4RL_cX17a8G6k': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 5250208',
#    'name': 'Kanwil DJP Jakarta Pusat',
#    'rating': 4.2},
#   'status': 'OK'},
#  'ChIJl4E46C70aS4R6I1kqrqUG4Y': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3506192',
#    'name': 'Kantor Akuntan Publik (KAP) Jojo Sunarjo, Ruchiat & Arifin'},
#   'status': 'OK'},
#  'ChIJ73iHqij0aS4RQO-CnZ1pUZo': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3901007',
#    'name': 'Okusi Associates',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJpUIxoSj0aS4RAK0s0LRJDCk': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3908907',
#    'name': 'Kap Ichwan, Kurniawan, Jauhari & Rekan',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJeXK7rCj0aS4R23IhfpuceFM': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3908952',
#    'name': 'IndoBiz Synergy Consulting. PT'},
#   'status': 'OK'},
#  'ChIJXXzdtNX1aS4RbV1CUD0zc5I': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3500103',
#    'name': 'Kantor Akuntan Publik (KAP) Benny, Tony, Frans & Daniel (Pusat)'},
#   'status': 'OK'},
#  'ChIJjTWglyr0aS4R_0mr7TVRfpA': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3865580',
#    'name': 'BADAN PENDAPATAN DAERAH',
#    'rating': 4.3},
#   'status': 'OK'},
#  'ChIJn47rRir0aS4RwDBl_wdukI0': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3446859',
#    'name': 'Kantor Akuntan Adnan Ali Drs'},
#   'status': 'OK'},
#  'ChIJn47rRir0aS4RHRFditbtI28': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3862088',
#    'name': 'Kantor Akuntan Publik Drs Supardan & Mulyana'},
#   'status': 'OK'},
#  'ChIJYb59ASz0aS4RhE8o8ZTWfUQ': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 2312955', 'name': 'ORS & Rekan'},
#   'status': 'OK'},
#  'ChIJazXOlir0aS4RwNBKSfzQu2s': {'html_attributions': [],
#   'result': {'name': 'UPPRD Gambir', 'rating': 4.5},
#   'status': 'OK'},
#  'ChIJbRQO2V31aS4RMmt4MAJ4lXI': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3454070',
#    'name': 'Kanwil DJP Jakarta Pusat'},
#   'status': 'OK'},
#  'ChIJIdCbKin0aS4RhGLUp2qSCnw': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3908909',
#    'name': 'Pers Kantor Akuntan Publik Rasin Ichwan & Co Drs'},
#   'status': 'OK'},
#  'ChIJQdHVYS70aS4ROsqT8wYdQuM': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3842483',
#    'name': 'Kantor Akuntan Publik Drs Sutrisno & Rekan'},
#   'status': 'OK'},
#  'ChIJkcjjIdX1aS4RiFpUUb_js2k': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3441651',
#    'name': 'Kantor Akuntan Drs JI Chamdani'},
#   'status': 'OK'},
#  'ChIJDek4KC30aS4R87zEY0E5ftk': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 5200660',
#    'name': 'KAP Tanubrata Sutanto Sibarani'},
#   'status': 'OK'},
#  'ChIJy5hgZC70aS4REoDdDrJinq8': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3506195',
#    'name': 'Kap Jojo Sunarto & Rekan'},
#   'status': 'OK'},
#  'ChIJmyX1aIz1aS4R7GMpRErMwEo': {'html_attributions': [],
#   'result': {'name': 'Pusat bantuan akulaku', 'rating': 5},
#   'status': 'OK'},
#  'ChIJ3e1FvrD3aS4RQq4NgWJH_uI': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0811-8681-705',
#    'name': 'PT. Khassana Solusi'},
#   'status': 'OK'},
#  'ChIJJeaMpCj0aS4RokATZeHi4iA': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 31928000',
#    'name': 'Kap Kosasih, Nurdiyaman Tjahjo & Partners'},
#   'status': 'OK'},
#  'ChIJHS_IuYz3aS4RFwXixQ31IcE': {'html_attributions': [],
#   'result': {'name': 'Stasiun Tanah Abang'},
#   'status': 'OK'},
#  'ChIJk2VzUoL2aS4Rnpq-lrmMfz0': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 31991228',
#    'name': 'Jade Taicindo Pratama',
#    'rating': 3.9},
#   'status': 'OK'},
#  'ChIJybn-uCj0aS4RhzEx4CqHS5Q': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0811-903-870',
#    'name': 'Keluarga Batik Betawi',
#    'rating': 4.6},
#   'status': 'OK'},
#  'ChIJb4_-6H_2aS4RuLmps0P9hAU': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3451898',
#    'name': "CAN'S Gallery",
#    'rating': 4.7},
#   'status': 'OK'},
#  'ChIJCUbYNNT1aS4RZmpOxXyLJnI': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3457130',
#    'name': "Andi's Gallery",
#    'rating': 4.3},
#   'status': 'OK'},
#  'ChIJDfc8jtT1aS4RRj5E4sYOBLI': {'html_attributions': [],
#   'result': {'name': 'Galeri Mio Indonesia'},
#   'status': 'OK'},
#  'ChIJZafEacb1aS4RjxWnkuEi5_Q': {'html_attributions': [],
#   'result': {'name': 'Patung MH Thamrin'},
#   'status': 'OK'},
#  'ChIJ9xTtEy_0aS4RVzYnU29wEE4': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3140258',
#    'name': 'Shinta',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJkVl3Cyb0aS4Raozs7exlO6E': {'html_attributions': [],
#   'result': {'name': 'Chandra Wella Painting'},
#   'status': 'OK'},
#  'ChIJkVl3Cyb0aS4RGprckLd4Cgs': {'html_attributions': [],
#   'result': {'name': 'Toraja Art'},
#   'status': 'OK'},
#  'ChIJe53G7Cr0aS4RvRKnp_c8JAQ': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 6128811', 'name': 'Lobby Bar'},
#   'status': 'OK'},
#  'ChIJ9TMWEYL2aS4R2JK55sew6gw': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 2303636',
#    'name': 'Lobby Lounge',
#    'rating': 4},
#   'status': 'OK'},
#  'ChIJmciCIyb0aS4RpY-adxeET1c': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 31936868',
#    'name': 'The Awan Lounge',
#    'rating': 4.4},
#   'status': 'OK'},
#  'ChIJ_fE94yX0aS4RtXXryXKvWvY': {'html_attributions': [],
#   'result': {'name': 'Afterhour Bar & Billiard', 'rating': 4.4},
#   'status': 'OK'},
#  'ChIJ43S9JC70aS4R_axzWcFceEs': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 2301122',
#    'name': 'Boulevard Lounge',
#    'rating': 4.5},
#   'status': 'OK'},
#  'ChIJobqu4SX0aS4RMAessBn6_Ms': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 39832047',
#    'name': 'Afterhour Sarinah',
#    'rating': 4.4},
#   'status': 'OK'},
#  'ChIJYzpmCib0aS4RepIVgR-TR-I': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 31926666',
#    'name': 'Masterpiece Family Karaoke and Bistro',
#    'rating': 4},
#   'status': 'OK'},
#  'ChIJcdfvd3T0aS4RXrHxDLuZT3k': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 31925633',
#    'name': 'The Jaya Pub',
#    'rating': 4.5},
#   'status': 'OK'},
#  'ChIJP0a2hCX0aS4RQHNQM5bfaYU': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 21390263',
#    'name': 'iLLua Restaurant',
#    'rating': 4.5},
#   'status': 'OK'},
#  'ChIJm66udyX0aS4RoLpXQmSmve8': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3912323',
#    'name': 'Gumarang Bar Ibis Jakarta Tamarin',
#    'rating': 4.1},
#   'status': 'OK'},
#  'ChIJe53G7Cr0aS4R61M_GIrq7V4': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 6128811',
#    'name': 'Happy Dragon'},
#   'status': 'OK'},
#  'ChIJVdz1r3T1aS4Rd6G5dvhvKDs': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 9800378',
#    'name': "Starbucks Ba'Be",
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJOcb3kTX1aS4RrP0mtZTRWQU': {'html_attributions': [],
#   'result': {'name': 'pino4dtogel'},
#   'status': 'OK'},
#  'ChIJXa9Edw31aS4RkoagpXjWBUI': {'html_attributions': [],
#   'result': {'name': 'Toko Bahagia', 'rating': 5},
#   'status': 'OK'},
#  'ChIJQ852Cib0aS4Rrz_hSKpx6pg': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 39832177',
#    'name': 'Inul Vizta',
#    'rating': 4.2},
#   'status': 'OK'},
#  'ChIJbZoZuSj0aS4RL4CyGjadpX0': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 2303078',
#    'name': 'Zen Karaoke',
#    'rating': 4.5},
#   'status': 'OK'},
#  'ChIJa5aXsyj0aS4RVV-oZQCYUN8': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 29932749',
#    'name': 'Lobby Lounge',
#    'rating': 4},
#   'status': 'OK'},
#  'ChIJY0MkEi_0aS4RmOzRMXkEYxI': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3846133', 'name': 'Malt'},
#   'status': 'OK'},
#  'ChIJmydMpyj0aS4RDX8UY36xZWk': {'html_attributions': [],
#   'result': {'name': 'Le Bistro & Casablanca Bar', 'rating': 4.6},
#   'status': 'OK'},
#  'ChIJYTfXGHj1aS4RkjOnUrWpDOo': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 39899022',
#    'name': 'Bang Bang Restaurant & Lounge',
#    'rating': 4.4},
#   'status': 'OK'},
#  'ChIJqb35qSj0aS4RYK9gCUTMzB4': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 39833303',
#    'name': 'PT Health & Beauty Indonesia'},
#   'status': 'OK'},
#  'ChIJ1TQRGYH2aS4RlEWl3ZOW40w': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3514654',
#    'name': 'Fmn Clinic',
#    'rating': 4.6},
#   'status': 'OK'},
#  'ChIJhfkBwSX0aS4RAcgwq-skq1M': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 2302403',
#    'name': 'Qiara Salon',
#    'rating': 4.3},
#   'status': 'OK'},
#  'ChIJW74h8JL1aS4ROHTRj1nBqQo': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 23581856',
#    'name': 'Benefit Cosmetics Central Department Store Grand Indonesia',
#    'rating': 4.4},
#   'status': 'OK'},
#  'ChIJzfeZJEnxaS4Rg0f2TWpixMU': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 29924244',
#    'name': 'Benefit Cosmetics Brow Bar Lounge',
#    'rating': 3.5},
#   'status': 'OK'},
#  'ChIJf9MPxS70aS4Rc42whnfdDk4': {'html_attributions': [],
#   'result': {'name': 'Wawa Salon', 'rating': 2.7},
#   'status': 'OK'},
#  'ChIJkyjR-yj0aS4RlJV045kWqcc': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0821-1555-888',
#    'name': 'Az-Zuhra House of Beauty',
#    'rating': 4.8},
#   'status': 'OK'},
#  'ChIJfWKiyIH2aS4RS7NAoGLSkhg': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3518583',
#    'name': 'qq elegant',
#    'rating': 4.2},
#   'status': 'OK'},
#  'ChIJl8imDNz3aS4RtkDnAHVILSo': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0813-9958-5871',
#    'name': 'Sanggar Galuh'},
#   'status': 'OK'},
#  'ChIJl18yEYL2aS4Rk8Vns1J9sZ0': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3904838',
#    'name': 'Queen Start Toko'},
#   'status': 'OK'},
#  'ChIJZbKC5Uf1aS4RRep-7r5MTZw': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0813-1862-9713',
#    'name': 'Dian Gogon Salon',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJvZruHdz1aS4RMMUQVwqjvYc': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0813-1810-3707',
#    'name': 'Lisa Anggra Makeup',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJ0wJOayj0aS4RfSXFIq6_r7I': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 54390763',
#    'name': 'Chandra Salon'},
#   'status': 'OK'},
#  'ChIJgbd3FuD1aS4REV-QoNaAAOw': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0821-1322-8324',
#    'name': "Win's Salon",
#    'rating': 4.4},
#   'status': 'OK'},
#  'ChIJN-TuQYL2aS4RLwAgmLpLwr8': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3917210',
#    'name': 'Umbui Mudung Toko'},
#   'status': 'OK'},
#  'ChIJN-TuQYL2aS4RW9q-UWNXqbc': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3917818',
#    'name': 'Putri Fauza Toko'},
#   'status': 'OK'},
#  'ChIJN-TuQYL2aS4R15owb-vrqlA': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3144867',
#    'name': 'Ridho Arip Toko'},
#   'status': 'OK'},
#  'ChIJN-TuQYL2aS4Rs4pum4ruhec': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3928925',
#    'name': 'Rahmat RezkyMu Toko'},
#   'status': 'OK'},
#  'ChIJN-TuQYL2aS4RMgJW-SQZz6Y': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3915215',
#    'name': 'Usha Mulya Toko'},
#   'status': 'OK'},
#  'ChIJN-TuQYL2aS4R9XJ3hisBD30': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3912870', 'name': 'Rafici Toko'},
#   'status': 'OK'},
#  'ChIJSUvanij0aS4RkMIDlBl-m0o': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 23583800',
#    'name': 'Line Cycles'},
#   'status': 'OK'},
#  'ChIJDVdfHtX1aS4RGjMechLbTMw': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3858080',
#    'name': 'PT Kredit Mart Indonesia'},
#   'status': 'OK'},
#  'ChIJe53G7Cr0aS4RGy4pqY-xzJE': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 62302127', 'name': 'Go Mobile'},
#   'status': 'OK'},
#  'ChIJQRF12IH2aS4REJHPus5v3RI': {'html_attributions': [],
#   'result': {'name': 'Toko Buku Air Molek'},
#   'status': 'OK'},
#  'ChIJb4rxtCj0aS4RmJ1BHObb2ek': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 39830017',
#    'name': 'PT. Widyadara',
#    'rating': 1},
#   'status': 'OK'},
#  'ChIJbcdIYyj0aS4RbtJQVlYL0lU': {'html_attributions': [],
#   'result': {'name': 'Toko Komik Indie', 'rating': 5},
#   'status': 'OK'},
#  'ChIJT-w_ADL0aS4RFxksW9p7Pg8': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3505607',
#    'name': 'Toko Sinar Kasih',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJ_6Bi39X1aS4RtBhTbeGxQ0U': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3523840',
#    'name': 'Swasembada Swakarya',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJQ852Cib0aS4RAwzPWdkM0Pw': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3146590',
#    'name': 'PT. Multi Lumaga Perkasa'},
#   'status': 'OK'},
#  'ChIJhQtG74L2aS4RFTwWFmR6KRA': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3147533',
#    'name': 'Toko SH Alaydrus',
#    'rating': 4.8},
#   'status': 'OK'},
#  'ChIJ8RUq3C_0aS4RQuuN4iCbNhs': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 9194063',
#    'name': 'Jaksa Cynthia Book'},
#   'status': 'OK'},
#  'ChIJ_dZvzEf1aS4Rc1Sr5-jAadg': {'html_attributions': [],
#   'result': {'name': 'bookstore'},
#   'status': 'OK'},
#  'ChIJUd5FstT1aS4RFsoja4PVbHY': {'html_attributions': [],
#   'result': {'name': 'Monas', 'rating': 4.6},
#   'status': 'OK'},
#  'ChIJSXRtxy30aS4ROLOejFjgJ8s': {'html_attributions': [],
#   'result': {'name': 'Balai Kota', 'rating': 4.6},
#   'status': 'OK'},
#  'ChIJsyCK1C70aS4R0I6qdjj5y3o': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 39833050',
#    'name': 'Mister Bean Coffee'},
#   'status': 'OK'},
#  'ChIJpzeEJi_0aS4R-KnVa8ECVQE': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 31934438',
#    'name': 'Kopi Oey',
#    'rating': 4.4},
#   'status': 'OK'},
#  'ChIJw6vK2C70aS4R9fGeA2j_Xis': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3161888',
#    'name': "Dre's Kopitiam",
#    'rating': 4.2},
#   'status': 'OK'},
#  'ChIJZ0yXWS70aS4RilzZdAeiYW8': {'html_attributions': [],
#   'result': {'name': 'Yellow Truck Coffee', 'rating': 4.7},
#   'status': 'OK'},
#  'ChIJFZ-wVS_0aS4RPA3z_KLULP4': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3160316',
#    'name': 'Oh La La Cafe',
#    'rating': 3.6},
#   'status': 'OK'},
#  'ChIJBcK1Ci_0aS4R2Dx_hCsB7ck': {'html_attributions': [],
#   'result': {'name': 'Smartfren Cafe', 'rating': 5},
#   'status': 'OK'},
#  'ChIJMZ5AZDr0aS4R8U3WGAFxqHY': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0813-1716-1705',
#    'name': 'Martabak Pizza Orins Jalan Sabang',
#    'rating': 4.6},
#   'status': 'OK'},
#  'ChIJH99-Iyb0aS4RBd912MK_SJw': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 31936868',
#    'name': 'Waha Kitchen',
#    'rating': 4.5},
#   'status': 'OK'},
#  'ChIJ801wIyb0aS4RLceC1-Ez7HY': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 31922988',
#    'name': '127 Cafe - Kosenda Hotel',
#    'rating': 4.5},
#   'status': 'OK'},
#  'ChIJ____vzz0aS4RpS6ewTM5ZLo': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3902761',
#    'name': 'Excelso',
#    'rating': 4.3},
#   'status': 'OK'},
#  'ChIJxw5ITzjzaS4R558IeYDfuMk': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0896-3683-9275',
#    'name': 'Ruang Tengah Cafe and Restaurant',
#    'rating': 4.3},
#   'status': 'OK'},
#  'ChIJR0QLrCj0aS4R1K24xUDsbiI': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 39833377',
#    'name': 'Starbucks Skyline Building',
#    'rating': 4.6},
#   'status': 'OK'},
#  'ChIJc9oZniX0aS4RxqoUHXQxBoQ': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0811-2131-267',
#    'name': 'Upnormal Coffee Roasters',
#    'rating': 4.4},
#   'status': 'OK'},
#  'ChIJI-X6JIf1aS4RGLXUSJO6vZg': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0877-5888-6160',
#    'name': 'Jus hj monir',
#    'rating': 4},
#   'status': 'OK'},
#  'ChIJFWeJijD1aS4RsyyqjWNiuGo': {'html_attributions': [],
#   'result': {'name': 'The Coffee Bean & Tea Leaf', 'rating': 4.4},
#   'status': 'OK'},
#  'ChIJ3bKTUYv1aS4RoAinM8jO7_Q': {'html_attributions': [],
#   'result': {'name': 'warung leha'},
#   'status': 'OK'},
#  'ChIJw2szpiv0aS4Rr0tQ175AzQk': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0811-8854-777',
#    'name': 'WOC Espress',
#    'rating': 4.5},
#   'status': 'OK'},
#  'ChIJYb59ASz0aS4RHXxqwTnVDKc': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3848412',
#    'name': 'Daihatsu Diesel Mfg Ltd'},
#   'status': 'OK'},
#  'ChIJLQ-6-tn1aS4RQsh2GZqjWLk': {'html_attributions': [],
#   'result': {'name': 'Promo XL7 Jakarta'},
#   'status': 'OK'},
#  'ChIJ7cr6GNX1aS4Rj8SvnFzoKB0': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3518365',
#    'name': 'PT. Putra Jama Sedaya'},
#   'status': 'OK'},
#  'ChIJ0-DAVb_1aS4R5YkzGnbuQ8I': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0878-8874-2006',
#    'name': 'BMW Dealership Indonesia',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJvXes0Cf1aS4RatUTZ0uijzs': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0878-7889-7054',
#    'name': 'Promo BMW Jakarta',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJcZEFoMr1aS4R-Rjd_b-Ux7M': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0822-9902-2295',
#    'name': 'Business Consultant BMW Thamrin - Nicholas',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJ9UkvWtX1aS4R6npVVhmzanc': {'html_attributions': [],
#   'result': {'name': 'My Green Oil'},
#   'status': 'OK'},
#  'ChIJ5Y92tCj0aS4Rbum0GJXDqZc': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 90286969',
#    'name': 'Isanva Mobil'},
#   'status': 'OK'},
#  'ChIJIddUaYL2aS4RI6wjD7jWdoo': {'html_attributions': [],
#   'result': {'name': 'PT Barito Berlian Motors', 'rating': 5},
#   'status': 'OK'},
#  'ChIJGXPRrCj0aS4RpZcqn7bOBB4': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 68881776',
#    'name': 'Bagus Auto Toko'},
#   'status': 'OK'},
#  'ChIJQbFmjX_2aS4RqVNPYZLcEA4': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0856-9290-4640', 'name': 'PT. AAT'},
#   'status': 'OK'},
#  'ChIJYxuOAA31aS4R0EZv_wvko6U': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0855-8862-000',
#    'name': 'Toyota-Indonesia',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJj5555Zz1aS4RXj9RYaS0ah8': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3912000',
#    'name': 'Auto2000 Wahid Hasyim',
#    'rating': 4.7},
#   'status': 'OK'},
#  'ChIJzZSzedD3aS4RV9QMWKP_kAY': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0889-7307-1886',
#    'name': 'Tokomobil.ID'},
#   'status': 'OK'},
#  'ChIJNZZCSH72aS4RIKo28eSsTpk': {'html_attributions': [],
#   'result': {'name': 'Showroom 54 jakarta pusat', 'rating': 5},
#   'status': 'OK'},
#  'ChIJiRzEuyj0aS4Rj9GjxZXYy18': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 31906314',
#    'name': 'Panen Rental',
#    'rating': 3},
#   'status': 'OK'},
#  'ChIJ__Ki24H2aS4RRBYRWPlbGHM': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0877-8833-8102',
#    'name': 'Sewa Mobil Pengantin Murah',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJ____v3_2aS4R88xeIbkEf38': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(0584) 6897468', 'name': 'Rental'},
#   'status': 'OK'},
#  'ChIJKeLE9SX0aS4RyeIisZZ-xNA': {'html_attributions': [],
#   'result': {'formatted_phone_number': '(021) 3926654',
#    'name': 'Pratama Mitra Sejati',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJq6qq6oL2aS4R-lcVixQMV8M': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0879-4675-48764',
#    'name': 'Rental Gratis'},
#   'status': 'OK'},
#  'ChIJE7KkVgL1aS4RV2VbfGGZO9U': {'html_attributions': [],
#   'result': {'name': 'SEKAR Rental'},
#   'status': 'OK'},
#  'ChIJeRlSc3P1aS4RUupYtxns6z8': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0813-8083-5156',
#    'name': 'A.arent@car'},
#   'status': 'OK'},
#  'ChIJQdifXBL3aS4RYoRDYBYysqc': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0878-8336-2841',
#    'name': 'Rental mobil srj',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJO0WLxYf3aS4Rv2FXK3sslJg': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0813-8128-8286',
#    'name': 'Sahabat Rentcar',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJFU_yCkH1aS4R7wLVPznwTcM': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0813-8048-9017',
#    'name': 'Sekar rental',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJh1CPXHf1aS4RMJrlzkS4gL8': {'html_attributions': [],
#   'result': {'name': 'WALET rental mobil jakarta pusat', 'rating': 5},
#   'status': 'OK'},
#  'ChIJyWQX9az3aS4RnN3UshLUtUk': {'html_attributions': [],
#   'result': {'name': 'Sukses Jaya Rental Mobil Murah', 'rating': 5},
#   'status': 'OK'},
#  'ChIJk7r0ICb0aS4RRbNzwE35x4c': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0813-1045-3922',
#    'name': 'sewa elf jakarta - Trisulatrans'},
#   'status': 'OK'},
#  'ChIJT9FgM_r1aS4RQDx0bQIsip8': {'html_attributions': [],
#   'result': {'name': 'SEWA MOBIL MURAH JAKARTA - KIAN RENTAL', 'rating': 5},
#   'status': 'OK'},
#  'ChIJ7xutlk_1aS4RM1rMz-uLGos': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0821-1362-2211',
#    'name': 'TRUST INDONESIA Rent A Car',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJ29-JYX_2aS4RNbxVsUJVYJk': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0895-3294-05086',
#    'name': 'Rental ELF 15-19 Seat',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJhUA-nHX1aS4R3C8zccbW9aw': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0878-7006-6667',
#    'name': 'Sewa Mobil Murah HD Rent',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJRy1_hET3aS4RtSxpFi8yLmQ': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0812-1316-6660',
#    'name': 'Rental mobil Gambir | Elsa rent car',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJwcb0pYv1aS4RwMPMeW4ZYy4': {'html_attributions': [],
#   'result': {'formatted_phone_number': '0857-5718-44094',
#    'name': 'Rental Putra Dewa Cbk',
#    'rating': 5},
#   'status': 'OK'},
#  'ChIJMXN112v1aS4RSPuedCNLwT0': {'html_attributions': [],
#   'result': {'name': 'Sewa mobil innova HDR'},
#   'status': 'OK'}}

# %%
(list(data_number.keys()))
# Out:
# ['ChIJkVl3Cyb0aS4RreuLHC1jVVs',
#  'ChIJ4aK0ASb0aS4RtBpG6E47-KU',
#  'ChIJ57QLxyr0aS4RT1xV2ruHnWQ',
#  'ChIJ94bINy70aS4RbUmWL0D6UrQ',
#  'ChIJ_yLtR4L2aS4RQajwWGcodnc',
#  'ChIJN84MlNT1aS4R9RzBpYTEojk',
#  'ChIJVcmszNT1aS4RwbX0jl6Zfao',
#  'ChIJQdHVYS70aS4Rxvwlm6N_58o',
#  'ChIJAZs2lCv0aS4RmiTJpV4nxr8',
#  'ChIJb1gXjSv0aS4RmbIRpsNYF9E',
#  'ChIJxY-DASz0aS4RAwxau8n6IIw',
#  'ChIJa0gFCSv0aS4R5UrOuZ7UqrA',
#  'ChIJR4e0yCv0aS4R33Mk1hwMieA',
#  'ChIJS8Z1TCr0aS4RZ9Xwvmbsj28',
#  'ChIJnb9o2Sv0aS4Rhv7bqHKNoVg',
#  'ChIJmVEx1yv0aS4RvWSbD7FmSdo',
#  'ChIJz8X1FSv0aS4RnlGa484ZwfY',
#  'ChIJo-Uxmyn0aS4RzA_4qTPht00',
#  'ChIJv_nANyr0aS4RmWjccz_eiYI',
#  'ChIJz4-DASz0aS4RHq5eQAANybw',
#  'ChIJN47oviv0aS4RV9VUw3DujB4',
#  'ChIJZd_7Lyz0aS4R1Tpt2YnzwQs',
#  'ChIJd7CgldT1aS4RrtJxWnsOu8s',
#  'ChIJl6wN6y70aS4RVN3Z1qOLLQM',
#  'ChIJX8PRLtT1aS4RFsARwtmhebo',
#  'ChIJA-6-USn0aS4RBwhMlG44Bs0',
#  'ChIJjYUSlSv0aS4RgGhvrnXEOAU',
#  'ChIJIYcuXCn0aS4RW1T3hhEKD4c',
#  'ChIJR0acfyn0aS4RJpC4p-F9k14',
#  'ChIJ1a2qhSn0aS4RHS7walswctE',
#  'ChIJDz3T9ir0aS4RE4YIisiMwIg',
#  'ChIJI2Mi6dT1aS4R_9QvMw2LbMA',
#  'ChIJzRh38tT1aS4RKCRxTOnaJGw',
#  'ChIJY4JB7dX1aS4RTixX44Ml7WA',
#  'ChIJtcGPOCb0aS4RqkaNusHU0kA',
#  'ChIJo4GjwCv0aS4RR07fUNdQEew',
#  'ChIJG9ZBECv0aS4RPjJKLHGzZU0',
#  'ChIJCVaPQCv0aS4R0LQf87JD3Fs',
#  'ChIJ1ScSBiz0aS4RlFXNe3a4KCs',
#  'ChIJtxr7bSz0aS4RtkpbepsFN40',
#  'ChIJ__8_Aiz0aS4RMq84IqUZJ6I',
#  'ChIJYb59ASz0aS4RtBEpd2MX3VE',
#  'ChIJM_wW3Cr0aS4Rt_o4d4Rc588',
#  'ChIJYT4Xnyr0aS4Rs5eubrMOoik',
#  'ChIJM1KCnCr0aS4RGAe0nZPwbX8',
#  'ChIJDdCDMdX1aS4R8-fORPjzk94',
#  'ChIJ4cwg6y70aS4Rmi60ABjBgEk',
#  'ChIJSZYq_RT1aS4RIMGdBH6f9Rk',
#  'ChIJ4YvOJdX1aS4Rces7LnYfgBU',
#  'ChIJ7fo4qyn0aS4RGUugb5dupaQ',
#  'ChIJ4aK0ASb0aS4RJvFYZjAod84',
#  'ChIJuf0yYmP1aS4RABndlp8cHog',
#  'ChIJY8xXuSr0aS4RlYxoGKKIaBU',
#  'ChIJvZJYPS_0aS4R1PXqoP5lKIM',
#  'ChIJpeBz1Cf0aS4RBstiaiOFX3k',
#  'ChIJu_xCVIL2aS4RdsznZ_xx2Uk',
#  'ChIJ7VieKi_0aS4RT3StCIsUhUQ',
#  'ChIJMxQfF4L2aS4RMZdVI3d5ra8',
#  'ChIJ_UFU6yj0aS4RWLItwmL4SIo',
#  'ChIJX7jblSj0aS4RJMGwEhjv5p8',
#  'ChIJuYos6yj0aS4RImWrQ1Yn0FQ',
#  'ChIJV3JslCj0aS4RLAqixbMRsaU',
#  'ChIJdYBPPC_0aS4R0P7ZCeeC7b4',
#  'ChIJ1wmkVS_0aS4R60bJyQQ3dk0',
#  'ChIJE6XGJSb0aS4RM7LGV2VP5uE',
#  'ChIJO04zPZ32aS4R0KITGrWF12I',
#  'ChIJSaJzPiH0aS4RHT4fHt69ceQ',
#  'ChIJ7UrAsTL0aS4R3-wUx1oKuco',
#  'ChIJrfbkzvL1aS4Rj-9ra4yRWj0',
#  'ChIJe53G7Cr0aS4RVt3CU9vx09w',
#  'ChIJg4qiuiH0aS4RDB3DtatwXvY',
#  'ChIJGfY6lAD1aS4RD0xb1eSgHrA',
#  'ChIJo7LhuSn0aS4RAdzTdKk7f1A',
#  'ChIJ15SGwCn0aS4RgBfKPYZAgAk',
#  'ChIJK-MqtoD1aS4R0qKEI_ggtRM',
#  'ChIJlRR73y70aS4RKM9L3hFvqRE',
#  'ChIJ62U3CFfxaS4RL_cX17a8G6k',
#  'ChIJl4E46C70aS4R6I1kqrqUG4Y',
#  'ChIJ73iHqij0aS4RQO-CnZ1pUZo',
#  'ChIJpUIxoSj0aS4RAK0s0LRJDCk',
#  'ChIJeXK7rCj0aS4R23IhfpuceFM',
#  'ChIJXXzdtNX1aS4RbV1CUD0zc5I',
#  'ChIJjTWglyr0aS4R_0mr7TVRfpA',
#  'ChIJn47rRir0aS4RwDBl_wdukI0',
#  'ChIJn47rRir0aS4RHRFditbtI28',
#  'ChIJYb59ASz0aS4RhE8o8ZTWfUQ',
#  'ChIJazXOlir0aS4RwNBKSfzQu2s',
#  'ChIJbRQO2V31aS4RMmt4MAJ4lXI',
#  'ChIJIdCbKin0aS4RhGLUp2qSCnw',
#  'ChIJQdHVYS70aS4ROsqT8wYdQuM',
#  'ChIJkcjjIdX1aS4RiFpUUb_js2k',
#  'ChIJDek4KC30aS4R87zEY0E5ftk',
#  'ChIJy5hgZC70aS4REoDdDrJinq8',
#  'ChIJmyX1aIz1aS4R7GMpRErMwEo',
#  'ChIJ3e1FvrD3aS4RQq4NgWJH_uI',
#  'ChIJJeaMpCj0aS4RokATZeHi4iA',
#  'ChIJHS_IuYz3aS4RFwXixQ31IcE',
#  'ChIJk2VzUoL2aS4Rnpq-lrmMfz0',
#  'ChIJybn-uCj0aS4RhzEx4CqHS5Q',
#  'ChIJb4_-6H_2aS4RuLmps0P9hAU',
#  'ChIJCUbYNNT1aS4RZmpOxXyLJnI',
#  'ChIJDfc8jtT1aS4RRj5E4sYOBLI',
#  'ChIJZafEacb1aS4RjxWnkuEi5_Q',
#  'ChIJ9xTtEy_0aS4RVzYnU29wEE4',
#  'ChIJkVl3Cyb0aS4Raozs7exlO6E',
#  'ChIJkVl3Cyb0aS4RGprckLd4Cgs',
#  'ChIJe53G7Cr0aS4RvRKnp_c8JAQ',
#  'ChIJ9TMWEYL2aS4R2JK55sew6gw',
#  'ChIJmciCIyb0aS4RpY-adxeET1c',
#  'ChIJ_fE94yX0aS4RtXXryXKvWvY',
#  'ChIJ43S9JC70aS4R_axzWcFceEs',
#  'ChIJobqu4SX0aS4RMAessBn6_Ms',
#  'ChIJYzpmCib0aS4RepIVgR-TR-I',
#  'ChIJcdfvd3T0aS4RXrHxDLuZT3k',
#  'ChIJP0a2hCX0aS4RQHNQM5bfaYU',
#  'ChIJm66udyX0aS4RoLpXQmSmve8',
#  'ChIJe53G7Cr0aS4R61M_GIrq7V4',
#  'ChIJVdz1r3T1aS4Rd6G5dvhvKDs',
#  'ChIJOcb3kTX1aS4RrP0mtZTRWQU',
#  'ChIJXa9Edw31aS4RkoagpXjWBUI',
#  'ChIJQ852Cib0aS4Rrz_hSKpx6pg',
#  'ChIJbZoZuSj0aS4RL4CyGjadpX0',
#  'ChIJa5aXsyj0aS4RVV-oZQCYUN8',
#  'ChIJY0MkEi_0aS4RmOzRMXkEYxI',
#  'ChIJmydMpyj0aS4RDX8UY36xZWk',
#  'ChIJYTfXGHj1aS4RkjOnUrWpDOo',
#  'ChIJqb35qSj0aS4RYK9gCUTMzB4',
#  'ChIJ1TQRGYH2aS4RlEWl3ZOW40w',
#  'ChIJhfkBwSX0aS4RAcgwq-skq1M',
#  'ChIJW74h8JL1aS4ROHTRj1nBqQo',
#  'ChIJzfeZJEnxaS4Rg0f2TWpixMU',
#  'ChIJf9MPxS70aS4Rc42whnfdDk4',
#  'ChIJkyjR-yj0aS4RlJV045kWqcc',
#  'ChIJfWKiyIH2aS4RS7NAoGLSkhg',
#  'ChIJl8imDNz3aS4RtkDnAHVILSo',
#  'ChIJl18yEYL2aS4Rk8Vns1J9sZ0',
#  'ChIJZbKC5Uf1aS4RRep-7r5MTZw',
#  'ChIJvZruHdz1aS4RMMUQVwqjvYc',
#  'ChIJ0wJOayj0aS4RfSXFIq6_r7I',
#  'ChIJgbd3FuD1aS4REV-QoNaAAOw',
#  'ChIJN-TuQYL2aS4RLwAgmLpLwr8',
#  'ChIJN-TuQYL2aS4RW9q-UWNXqbc',
#  'ChIJN-TuQYL2aS4R15owb-vrqlA',
#  'ChIJN-TuQYL2aS4Rs4pum4ruhec',
#  'ChIJN-TuQYL2aS4RMgJW-SQZz6Y',
#  'ChIJN-TuQYL2aS4R9XJ3hisBD30',
#  'ChIJSUvanij0aS4RkMIDlBl-m0o',
#  'ChIJDVdfHtX1aS4RGjMechLbTMw',
#  'ChIJe53G7Cr0aS4RGy4pqY-xzJE',
#  'ChIJQRF12IH2aS4REJHPus5v3RI',
#  'ChIJb4rxtCj0aS4RmJ1BHObb2ek',
#  'ChIJbcdIYyj0aS4RbtJQVlYL0lU',
#  'ChIJT-w_ADL0aS4RFxksW9p7Pg8',
#  'ChIJ_6Bi39X1aS4RtBhTbeGxQ0U',
#  'ChIJQ852Cib0aS4RAwzPWdkM0Pw',
#  'ChIJhQtG74L2aS4RFTwWFmR6KRA',
#  'ChIJ8RUq3C_0aS4RQuuN4iCbNhs',
#  'ChIJ_dZvzEf1aS4Rc1Sr5-jAadg',
#  'ChIJUd5FstT1aS4RFsoja4PVbHY',
#  'ChIJSXRtxy30aS4ROLOejFjgJ8s',
#  'ChIJsyCK1C70aS4R0I6qdjj5y3o',
#  'ChIJpzeEJi_0aS4R-KnVa8ECVQE',
#  'ChIJw6vK2C70aS4R9fGeA2j_Xis',
#  'ChIJZ0yXWS70aS4RilzZdAeiYW8',
#  'ChIJFZ-wVS_0aS4RPA3z_KLULP4',
#  'ChIJBcK1Ci_0aS4R2Dx_hCsB7ck',
#  'ChIJMZ5AZDr0aS4R8U3WGAFxqHY',
#  'ChIJH99-Iyb0aS4RBd912MK_SJw',
#  'ChIJ801wIyb0aS4RLceC1-Ez7HY',
#  'ChIJ____vzz0aS4RpS6ewTM5ZLo',
#  'ChIJxw5ITzjzaS4R558IeYDfuMk',
#  'ChIJR0QLrCj0aS4R1K24xUDsbiI',
#  'ChIJc9oZniX0aS4RxqoUHXQxBoQ',
#  'ChIJI-X6JIf1aS4RGLXUSJO6vZg',
#  'ChIJFWeJijD1aS4RsyyqjWNiuGo',
#  'ChIJ3bKTUYv1aS4RoAinM8jO7_Q',
#  'ChIJw2szpiv0aS4Rr0tQ175AzQk',
#  'ChIJYb59ASz0aS4RHXxqwTnVDKc',
#  'ChIJLQ-6-tn1aS4RQsh2GZqjWLk',
#  'ChIJ7cr6GNX1aS4Rj8SvnFzoKB0',
#  'ChIJ0-DAVb_1aS4R5YkzGnbuQ8I',
#  'ChIJvXes0Cf1aS4RatUTZ0uijzs',
#  'ChIJcZEFoMr1aS4R-Rjd_b-Ux7M',
#  'ChIJ9UkvWtX1aS4R6npVVhmzanc',
#  'ChIJ5Y92tCj0aS4Rbum0GJXDqZc',
#  'ChIJIddUaYL2aS4RI6wjD7jWdoo',
#  'ChIJGXPRrCj0aS4RpZcqn7bOBB4',
#  'ChIJQbFmjX_2aS4RqVNPYZLcEA4',
#  'ChIJYxuOAA31aS4R0EZv_wvko6U',
#  'ChIJj5555Zz1aS4RXj9RYaS0ah8',
#  'ChIJzZSzedD3aS4RV9QMWKP_kAY',
#  'ChIJNZZCSH72aS4RIKo28eSsTpk',
#  'ChIJiRzEuyj0aS4Rj9GjxZXYy18',
#  'ChIJ__Ki24H2aS4RRBYRWPlbGHM',
#  'ChIJ____v3_2aS4R88xeIbkEf38',
#  'ChIJKeLE9SX0aS4RyeIisZZ-xNA',
#  'ChIJq6qq6oL2aS4R-lcVixQMV8M',
#  'ChIJE7KkVgL1aS4RV2VbfGGZO9U',
#  'ChIJeRlSc3P1aS4RUupYtxns6z8',
#  'ChIJQdifXBL3aS4RYoRDYBYysqc',
#  'ChIJO0WLxYf3aS4Rv2FXK3sslJg',
#  'ChIJFU_yCkH1aS4R7wLVPznwTcM',
#  'ChIJh1CPXHf1aS4RMJrlzkS4gL8',
#  'ChIJyWQX9az3aS4RnN3UshLUtUk',
#  'ChIJk7r0ICb0aS4RRbNzwE35x4c',
#  'ChIJT9FgM_r1aS4RQDx0bQIsip8',
#  'ChIJ7xutlk_1aS4RM1rMz-uLGos',
#  'ChIJ29-JYX_2aS4RNbxVsUJVYJk',
#  'ChIJhUA-nHX1aS4R3C8zccbW9aw',
#  'ChIJRy1_hET3aS4RtSxpFi8yLmQ',
#  'ChIJwcb0pYv1aS4RwMPMeW4ZYy4',
#  'ChIJMXN112v1aS4RSPuedCNLwT0']

# %%
datanumb = pd.DataFrame.from_dict(data_number).T.reset_index()
datanumb.columns = ['place_id','html_attributions','result','status']
datanumb
# Out:
#                         place_id html_attributions  \
# 0    ChIJkVl3Cyb0aS4RreuLHC1jVVs                []
# 1    ChIJ4aK0ASb0aS4RtBpG6E47-KU                []
# 2    ChIJ57QLxyr0aS4RT1xV2ruHnWQ                []
# 3    ChIJ94bINy70aS4RbUmWL0D6UrQ                []
# 4    ChIJ_yLtR4L2aS4RQajwWGcodnc                []
# ..                           ...               ...
# 207  ChIJ29-JYX_2aS4RNbxVsUJVYJk                []
# 208  ChIJhUA-nHX1aS4R3C8zccbW9aw                []
# 209  ChIJRy1_hET3aS4RtSxpFi8yLmQ                []
# 210  ChIJwcb0pYv1aS4RwMPMeW4ZYy4                []
# 211  ChIJMXN112v1aS4RSPuedCNLwT0                []
#
#                                                 result status
# 0                   {'name': 'ATM BCA', 'rating': 4.5}     OK
# 1    {'formatted_phone_number': '(021) 2300644', 'n...     OK
# 2    {'formatted_phone_number': '(021) 1500016', 'n...     OK
# 3    {'formatted_phone_number': '(021) 2302411', 'n...     OK
# 4    {'formatted_phone_number': '(021) 2302411', 'n...     OK
# ..                                                 ...    ...
# 207  {'formatted_phone_number': '0895-3294-05086', ...     OK
# 208  {'formatted_phone_number': '0878-7006-6667', '...     OK
# 209  {'formatted_phone_number': '0812-1316-6660', '...     OK
# 210  {'formatted_phone_number': '0857-5718-44094', ...     OK
# 211                  {'name': 'Sewa mobil innova HDR'}     OK
#
# [212 rows x 4 columns]

# %%
datanumb['result'][0].keys()
# Out:
# dict_keys(['name', 'rating'])

# %%
name= []
phone=[]

for number in range(len(datanumb)):
    name.append(datanumb['result'][number]['name'])
    if 'formatted_phone_number' in (datanumb['result'][number].keys()):
        phone.append(datanumb['result'][number]['formatted_phone_number'])
    else:
        phone.append(0)

# %%
datanumb2 = pd.DataFrame({'name':name,'phone number':phone})
datanumb2['place_id'] = datanumb['place_id']
datanumb2
# Out:
#                                     name     phone number  \
# 0                                ATM BCA                0
# 1                           Bank Mandiri    (021) 2300644
# 2           ATM Muamalat SPBU Abdul Muis    (021) 1500016
# 3         ATM Bank Mandiri Setoran Tunai    (021) 2302411
# 4                        Wisma Mandiri 2    (021) 2302411
# ..                                   ...              ...
# 207                Rental ELF 15-19 Seat  0895-3294-05086
# 208             Sewa Mobil Murah HD Rent   0878-7006-6667
# 209  Rental mobil Gambir | Elsa rent car   0812-1316-6660
# 210                Rental Putra Dewa Cbk  0857-5718-44094
# 211                Sewa mobil innova HDR                0
#
#                         place_id
# 0    ChIJkVl3Cyb0aS4RreuLHC1jVVs
# 1    ChIJ4aK0ASb0aS4RtBpG6E47-KU
# 2    ChIJ57QLxyr0aS4RT1xV2ruHnWQ
# 3    ChIJ94bINy70aS4RbUmWL0D6UrQ
# 4    ChIJ_yLtR4L2aS4RQajwWGcodnc
# ..                           ...
# 207  ChIJ29-JYX_2aS4RNbxVsUJVYJk
# 208  ChIJhUA-nHX1aS4R3C8zccbW9aw
# 209  ChIJRy1_hET3aS4RtSxpFi8yLmQ
# 210  ChIJwcb0pYv1aS4RwMPMeW4ZYy4
# 211  ChIJMXN112v1aS4RSPuedCNLwT0
#
# [212 rows x 3 columns]

# %% [markdown]
# # join

# %%
datamerge=datacustype.merge(datanumb2, how='left', on='place_id')
#datagab3=datab2.join(datanumb2.set_index('place_id'),on='place_id')
datamerge
# Out:
#                                   name_x                     place_id  \
# 0                                ATM BCA  ChIJkVl3Cyb0aS4RreuLHC1jVVs
# 1                           Bank Mandiri  ChIJ4aK0ASb0aS4RtBpG6E47-KU
# 2           ATM Muamalat SPBU Abdul Muis  ChIJ57QLxyr0aS4RT1xV2ruHnWQ
# 3         ATM Bank Mandiri Setoran Tunai  ChIJ94bINy70aS4RbUmWL0D6UrQ
# 4                        Wisma Mandiri 2  ChIJ_yLtR4L2aS4RQajwWGcodnc
# ..                                   ...                          ...
# 220                Rental ELF 15-19 Seat  ChIJ29-JYX_2aS4RNbxVsUJVYJk
# 221             Sewa Mobil Murah HD Rent  ChIJhUA-nHX1aS4R3C8zccbW9aw
# 222  Rental mobil Gambir | Elsa rent car  ChIJRy1_hET3aS4RtSxpFi8yLmQ
# 223                Rental Putra Dewa Cbk  ChIJwcb0pYv1aS4RwMPMeW4ZYy4
# 224                Sewa mobil innova HDR  ChIJMXN112v1aS4RSPuedCNLwT0
#
#           types  latitude   longitude  \
# 0           atm -6.187770  106.823922
# 1          bank -6.187334  106.823601
# 2           atm -6.178355  106.818414
# 3           atm -6.183710  106.823645
# 4          bank -6.184070  106.823523
# ..          ...       ...         ...
# 220  car_rental -6.173132  106.817717
# 221  car_rental -6.185073  106.828367
# 222  car_rental -6.180555  106.813822
# 223  car_rental -6.187180  106.818271
# 224  car_rental -6.185634  106.828251
#
#                                                address  \
# 0      Jalan M.H. Thamrin No.11, RT.8/RW.4, Gondangdia
# 1      Jalan M.H. Thamrin No.11, RT.8/RW.4, Gondangdia
# 2    Jalan Abdul Muis No. 59, RT.4/RW.3, Petojo Sel...
# 3    Wisma Mandiri, Jalan Kebon Sirih No.83, RT.2/R...
# 4      Jalan Kebon Sirih No.83, RT.2/RW.1, Kebon Sirih
# ..                                                 ...
# 220  Jalan Petojo Enclek XIII No.22, RT.16/RW.7, Pe...
# 221  Jalan Kebon Sirih Barat I No.33-35, RT.13/RW.2...
# 222   13, Jalan Kebon Jahe No.54, RW.2, Petojo Selatan
# 223                         2, RT.5/RW.5, Kebon Kacang
# 224                             RT.8/RW.4, Kebon Sirih
#
#                                   name_y     phone number
# 0                                ATM BCA                0
# 1                           Bank Mandiri    (021) 2300644
# 2           ATM Muamalat SPBU Abdul Muis    (021) 1500016
# 3         ATM Bank Mandiri Setoran Tunai    (021) 2302411
# 4                        Wisma Mandiri 2    (021) 2302411
# ..                                   ...              ...
# 220                Rental ELF 15-19 Seat  0895-3294-05086
# 221             Sewa Mobil Murah HD Rent   0878-7006-6667
# 222  Rental mobil Gambir | Elsa rent car   0812-1316-6660
# 223                Rental Putra Dewa Cbk  0857-5718-44094
# 224                Sewa mobil innova HDR                0
#
# [225 rows x 8 columns]

# %%
pd.isnull(datamerge).sum()
# Out:
# name_x          0
# place_id        0
# types           0
# latitude        0
# longitude       0
# address         0
# name_y          0
# phone number    0
# dtype: int64
